# %% [markdown]
# # Pre-class Homework HW0 - Python Intro and Review
#
# ---
#
# _First things first --  Save a copy of this notebook in your own Google drive.  This will be necessary whenever you use one of the class notebooks.  Get into this habit and it will prevent cases where you have made changes but cannot save them!_
#
# ---
#
# Submit this Assignment to Brightspace in the form of a file named **`lastname_firstname.ipynb`** AND as a pdf in the form of **`lastname_firstname.pdf`
#
# ---
#
#
# As noted in the Syllabus, this class is intended for those who already are familiar with Python.  We have created a few notebooks for you to go through to make sure this class is at the right level for you.
#
# In class we will be using Google Colab as our Python development environment.  For those not familiar with Colab, it is a cloud-based IDE that makes it easy to share notebooks and data and work jointly with others.  Some of you may use other IDEs (Jupyter, VSCode,  Anaconda Spyder, or other) – that is fine – these are similar notebook-based environments that run locally on your machine instead of on the cloud.    However, all of the examples in class and homeworks will be done using Colab, so it will be good to be familiar with it.
#
# **This assigment will be graded by completion only.**
#
# To get a refresher on Colab, Jupyter Notebooks, and Python basics, walk through the following notebooks and the links therein.  (Nothing to be handed in).  You should be comfortable with this material.
#
#
# * <a href="https://colab.research.google.com/drive/1jTgzo7w1YPxcZEIJgy7Bhg8z0VUqkXTb" target="_parent">Intro to Python / Jupyter Notebooks / Google Colab</a>
#
# If you get a page that looks like this:
#
# ![Colab_screen.png](https://drive.google.com/uc?export=view&id=1jQ-5XUTCeMQt5w-aAR5w6Id_1KfGtbH8)
#
#
# just click on the "Open with Google Colaboratory" link at the top.
#
#
#
# Complete the Python tasks below - this should either be review, or should be fairly simple for you to accomplish.  If this is a challenge, you may not be at the right level for the class.

# %% [markdown]
# ##  Python review

# %% [markdown]
# This part is intended to review some Basic Python tasks.  These are the types of basic manipulation tasks in Python that you should either know, or be able to figure out fairly quickly.   You may use the _generate_ function to help you, but why not try to see if you can figure them out for yourself first???

# %% [markdown]
# **hey, did you remember to save this notebook to your own Google Drive before starting ?? **

# %% [markdown]
# **1. Define two variables and assign an integer to the first and a float to the second. Define a new variable and assign the sum of the previous two variables. What's the data type of the third variable?**

# %% [markdown]
# **2. Create a Python list containing 5 unique fruits.**

# %% [markdown]
# **3. Create a second list by sorting the names of the list of fruits (in alphabetical order) using a Python function.**

# %% [markdown]
# **4. Create a new empty list called `count_letters`. Loop through your list of sorted fruits, and for each one, append an entry to `count_letters` providing the number of letters each fruit name (can do this with the python function `len`).   Use a print statement to output a sentence stating how many letters each fruit has.**
#
# Example of what you should print for one fruit: _apple is 5 letters_

# %% [markdown]
# **5. Create a function called `do_calc` that takes a list (input_list) and returns a new list (output_list) where each element of the original will be increased by 1 and divided by 2.**

# %%
def do_calc(input_list):
    output_list = []
    # Your code goes here!

    return output_list

# %% [markdown]
# **6.  Use the `do_calc`function from the last question to apply the function to the members of count_letters.  Print both lists.**

# %% [markdown]
# ---
#
# ##Submit this Assignment to Brightspace in the form of a file named **`lastname_firstname.ipynb`** AND as a pdf in the form of **`lastname_firstname.pdf`
#
# ---
