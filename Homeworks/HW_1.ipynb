# %% [markdown]
# # REMEMBER TO SAVE THIS NOTEBOOK TO YOUR OWN GOOGLE DRIVE!
#
# ##Please submit homework to Brightspace in the form of a file named **`lastname_firstname.ipynb`** AND as a pdf in the form of **`lastname_firstname.pdf`**

# %% [markdown]
# # Homework 1: Graduate admissions case study

# %% [markdown]
# You've been hired by Hudson University as a data analyst for the Graduate Admissions Department. Since the admission process is long and tedious, it often results in a bottleneck for other subsequent tasks, such as planning the necessary resources to accommodate the admitted students (e.g. housing, classes, etc). You have been asked to build a model to predict which students will be admitted using the following historical data:
#
# 1. Serial No. (serves as unique identifier)
# 2. GRE Scores (out of 340)
# 3. TOEFL Scores (out of 120)
# 4. University Rating (out of 5).
# 5. Statement of Purpose Strength (out of 5)
# 6. Letter of Recommendation Strength (out of 5)
# 7. Undergraduate GPA (out of 10)
# 8. Research Experience (either 0 or 1)
# 9. Chance of admission (ranging from 0 to 1)
#
# The chances of admission for the applicants in your data were assessed by an expert. Given that this list of application attributes would be available early in the admission process for future applications (except for Chance of admission), a model predicting chances of admission would allow planning tasks to start earlier.

# %% [markdown]
# ## Download and import the data
#
#
# [Clicking here should download the data to your machine](https://drive.google.com/uc?export=download&id=1qegVDL95gjRy1P3rz7Ue43AzZG7SA1Mm) as a file called HudsonU.csv.  Place this file on your Google Drive for upload in the next section..

# %% [markdown]
# **Load the HudsonU data into a pandas data frame and import the key Python packages.

# %%
# Some libraries you may need
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Trick to display plots inline with the rest of your notebook.
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')

# fill in the path to your Google Drive here
data_path = "/content/drive/MyDrive/YOUR_GOOGLE_DRIVE_PATH/HudsonU.csv"


admissions=pd.read_csv(data_path)
#YOUR CODE HERE

# %% [markdown]
# **1. How many rows and columns are in the data?**

# %%
#YOUR CODE HERE

# %% [markdown]
# **2. Rename the columns in the dataframe to manipulate the data more easily. This will make your life easier.  Show a few lines with the new column names.**

# %%
# Put your answer here.

# Here are some suggested column names: "ID", "GRE", "TOEFL", "Rating", "SOP", "LOR", "CGPA", "Research", "Admission"

# %% [markdown]
# **3. Show descriptive statistics for all columns.**

# %%
#YOUR CODE HERE

# %% [markdown]
# **4. What is the distribution of the chances of admission? Plot a histogram of
# this variable. Using arguments for plt.hist, play with the variables 'color', 'alpha', and 'edgecolor' to create a histogram with blue bars, and black outlines around the bars.  Draw a red vertical dashed line on the histogram at the median value.**

# %%
#YOUR CODE HERE

# %% [markdown]
# **5. Chances of admission seem to vary quite a bit. How much of this depends on research experience? Find the average chance of Admission for the different levels of Research. (this can be done using a groupby) - interpret the results (by adding a comment in the notebook)**

# %%
#YOUR CODE HERE

# %% [markdown]
# **6. Does the distribution of chances of admission change with university rating? Plot a histogram of chances of admission for each university rating. Plot 5 histograms - with vertical line at the median for each histogram. Interpret what you learn from the plots. Plot all histograms with the same range on the X-axis to aid in comparisons.**

# %%
#YOUR CODE HERE

# %% [markdown]
# **7. Another way to look at the relationship between two variables is through scatter plots. Plot a scatter plot between TOEFL Score and Admission.  Make sure to label the axes. How would you describe this relationship?**

# %%
#YOUR CODE HERE

# %% [markdown]
# **8. Boxplots are also useful to look at the relationship between a categorical variable and a numeric variable. Plot a boxplot of chance of Admission grouped by "University Rating". (check out the *seaborn* library)**

# %%
#YOUR CODE HERE

# %% [markdown]
# **9. The boxplots above show some outliers.  In particular the box for 'University Rating' = 5 has some cases with lower 'Chance of admission'.  Can you identify which case (by serial number) has the lowest Chance of admission but comes from a university with Rating = 5?**

# %%
#YOUR CODE HERE

# %% [markdown]
# **10. Drop the column for Serial Number. It is not useful for the following summarization and modelling tasks.**

# %%
#YOUR CODE HERE

# %% [markdown]
# **11. Very often it is useful to quantify how strong is the relationship between different features. Correlation allows us to measure the linear realationship between two features.  Display the correlations between all pairs of features using a seaborn heatmap. Round values to two decimal places.**(use appropriate color palette and max/min values See our `T3_DataViz.ipynb` Module for hints - )

# %%
#YOUR CODE HERE

# %% [markdown]
# **12. Based on the heatmap from the previous plot, which pairs of variables are most closely correlated? Which variable seems to give the most information on chance of admission?**

# %%
#YOUR CODE HERE

# %% [markdown]
# **13. Build a linear model to predict the chance of admission using the application info available. Use an 80/20 train/test split.  Generate predictions and compare predicted quantity to the actual value in a scatter plot. Print the Root Mean Squared Error (RMSE) for your predictions (dont forget to round!) and interpret the RMSE.**

# %%
#YOUR CODE HERE

# %% [markdown]
# **14. Describe how the admissions team might take action to use the results of this model to aid in the admissions process.  Specifically what actions could they take, and what might the impact be of an effective model.  Also, discuss any ethical concerns you may see with using this data for this purpose**

# %% [markdown]
# => Click to provide answer here

# %% [markdown]
# ##Please submit homework to Brightspace in the form of a file named `lastname_firstname.ipynb`
